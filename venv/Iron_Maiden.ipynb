# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{id}'

# %%
id_im = '6mdiAmATAx73kdxrNrnlao'

# %%
url_base+ep_artist.format(id=id_im)
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
import requests

# %%
r = requests.get(url_base+ep_artist.format(id=id_im))

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %%
headers = {'Authorization': 'Basic YmYwODdkNDBmNjQ5NGNkYmExNzI3NTgwZjJkNDZhYzU6Yjg4MzhiZTEwMGVmNDE0Mjk5YjYxMzlmMzNmZGY4ZjI='}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQC_bwvvpghl-sI2DQLTwszfG83gFWnaYuaw39fKkC-F4m_WmzmKyA0etqc-VSN3yRMm9tN48NO0q29oQzE',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
r = requests.get(url_base+ep_artist.format(id=id_im), headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 5780911},
#  'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/6dc0be659ea462b84b9b6485bc20db8dffaa48e2',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/a6e9ed559db89eaa89de1684eea49547128d598a',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/0481117ea43da1761cc597b85ef9a026b808420d',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':"Iron+Maiden", 'type':'artist', 'market':'PE'}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Iron%2BMaiden&type=artist&market=PE&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'followers': {'href': None, 'total': 5780911},
#     'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6dc0be659ea462b84b9b6485bc20db8dffaa48e2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/a6e9ed559db89eaa89de1684eea49547128d598a',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/0481117ea43da1761cc597b85ef9a026b808420d',
#       'width': 160}],
#     'name': 'Iron Maiden',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/5...
# 2  {'spotify': 'https://open.spotify.com/artist/2...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                           followers  \
# 0  {'href': None, 'total': 5780911}
# 1     {'href': None, 'total': 2019}
# 2      {'href': None, 'total': 688}
# 3     {'href': None, 'total': 1124}
# 4      {'href': None, 'total': 384}
#
#                                          genres  \
# 0  [album rock, hard rock, metal, nwobhm, rock]
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
#
#                                                 href                      id  \
# ...

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf8'))
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic '+str(encoded, 'utf8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None
    print('Token válido por {} segundos'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = 'bf087d40f6494cdba1727580f2d46ac5'

# %%
client_secret = 'b8838be100ef414299b6139f33fdf8f2'

# %%
token = get_token(client_id, client_secret)
# Out:
# Token válido por 3600 segundos

# %%
token
# Out:
# 'BQBjDpgNtT65BWNpngF53Xi6iNjCYrrZ7G9vipZ3SnZx4IFFFOTblgEZhxd_HHcDXOZkb03GfviEjEZPj0k'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
id_im
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
ep_albums = '/artists/{id}/albums'

# %%
url_base+ep_albums
# Out:
# 'https://api.spotify.com/v1/artists/{id}/albums'

# %%
params = {'country':'PE'}

# %%
albums_im = requests.get(url_base+ep_albums.format(id=id_im), headers=header, params=params)

# %%
albums_im.status_code
# Out:
# 200

# %%
albums_im.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#    'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#    'id': '6mdiAmATAx73kdxrNrnlao',
#    'name': 'Iron Maiden',
#    'type': 'artist',
#    'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#  'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#  'id': '3oFAX7PeOFbZnKiPmpUPv4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#    'width': 64}],
#  'name': 'The Book of Souls: Live Chapter',
# ...

# %%
lista_albums = [(album['id'], album['name']) for album in albums_im.json()['items']]
lista_albums
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock In Rio [Live]'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
#  ('4olc018Cln2QaMRFy1sk7v', 'Virtual XI (2015 Remaster)'),
#  ('3irqbaStVsDR9IEdg8Cdwz', 'The X Factor (2015 Remaster)'),
#  ('3DRvgymMVPG0TQ2DugHJRb', 'A Real Live Dead One (Live; 1998 Remaster)'),
#  ('77SZJrj0HAxMGvZtDzhvw7', 'Live at Donington (1998 Remaster)'),
# ...

# %%
album_ep = '/albums/{id}'
album_params = {'market':'PE'}

# %%
fod_id = '16Su3EUFLPqWVyrwN1q5wO'

# %%
fod = requests.get(url_base+album_ep.format(id=fod_id)+'/tracks', headers=header, params=params)
fod
# Out:
# <Response [200]>

# %%
fod.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
# ...

# %%
[(track['id'], track['name']) for track in fod.json()['items']]
# Out:
# [('7xa3dJQMzBVzsrZ81tNcHP', 'Be Quick or Be Dead - 2015 Remaster'),
#  ('6uXD7ywanNw6sGatkT9uVw', 'From Here to Eternity - 2015 Remaster'),
#  ('6QKhecJ2JuajCTPTtYkKUQ', 'Afraid to Shoot Strangers - 2015 Remaster'),
#  ('6VVnTDgxsyRyiyyWnGvdJH', 'Fear Is the Key - 2015 Remaster'),
#  ('3KCdBOxFWILICAH8vvSFny', "Childhood's End - 2015 Remaster"),
#  ('2KKLuHN6zDxVnWtFKO8vo4', 'Wasting Love - 2015 Remaster'),
#  ('3RMlIPEzFLbcEQwUFw2VA5', 'The Fugitive - 2015 Remaster'),
#  ('28JhcFgvq6WIHDosOSou4K', 'Chains of Misery - 2015 Remaster'),
#  ('4PF6Y2kNliZKQ8i1zG6B3v', 'The Apparition - 2015 Remaster'),
#  ('3JzdNBmwnV4trRNaXEx23Y', 'Judas Be My Guide - 2015 Remaster'),
#  ('1p3VX4AHb54jMpVJmVNBQG', 'Weekend Warrior - 2015 Remaster'),
#  ('6p8eFfPw3nQkf37aT3AkmK', 'Fear of the Dark - 2015 Remaster')]
